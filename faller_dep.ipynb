# %%
import EEGene
import misc
import Benchmarks
from EEGene import EEGene,Processing
from misc import Experiment,Data_Loader,Baseline_model
# Out:
# 2022-12-05 22:06:30.416317: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-05 22:06:30.416355: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:54: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.1.0 and strictly below 2.3.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# ...

# %%
DL = Data_Loader()
X_faller,y_faller = DL.load_faller(sub=-1,fmin=0.5,fmax=50)
# Out:
# Choosing from all possible events

# %%
import numpy as np
scores = []
for sub in range(len(X_faller)):
    print('SUB = ',sub)
    faller_dep = Experiment.single_subject_dependent_cv(X_faller[sub],y_faller[sub],
                                                        seed=0,verbose=1,model_name='faller_dep_sub_1in'+str(sub),
                                                        benchmarks=['EEGNet','DeepConvNet','EEGene']
                                                       )
    scores.append(faller_dep)
    np.save('final_report/faller_dep_1in.npy',scores)
# Out:
# SUB =  0
# batch : 0
# (320, 13, 500) (80, 13, 500)
# method =  covariance
# method =  raw
# method =  fft2
# method =  fft
# method =  cross_correlate
# method =  maxmin
# method =  meanstd
# method =  variance
# method =  spectral_entropy
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
# ...

# %%
Experiment.make_final_report(scores)
# Out:
#               method  accuracy  +-acc  f1-score  +-f1
# 12            EEGene     75.11  13.66     74.36 14.55
# 11       DeepConvNet     73.17  17.12     73.10 17.33
# 9                all     71.78  14.56     70.78 15.74
# 0         covariance     71.25  11.86     70.59 12.74
# 4    cross_correlate     71.07  15.48     69.41 17.18
# 7           variance     68.47  12.25     67.73 13.14
# 6            meanstd     68.26  11.93     67.77 12.14
# 10            EEGNet     62.93  14.41     63.59 15.78
# 1                raw     62.86   7.05     60.99  8.60
# 8   spectral_entropy     61.80  11.10     60.59 11.85
# 3                fft     59.04  10.78     56.09 12.18
# 5             maxmin     58.42   9.07     56.39  9.99
# 2               fft2     57.54   7.69     55.20  8.72
