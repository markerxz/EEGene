# %%
import EEGene
import misc
import Benchmarks
from EEGene import EEGene,Processing
from misc import Experiment,Data_Loader,Baseline_model
# Out:
# 2022-12-05 22:05:07.972457: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-05 22:05:07.972493: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:54: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.1.0 and strictly below 2.3.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# ...

# %%
DL = Data_Loader()
X_zhou,y_zhou = DL.load_zhou(sub=-1,fmin=0.5,fmax=50)
# Out:
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/moabb/datasets/Zhou2016.py:102: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/moabb/datasets/Zhou2016.py:102: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# Reading 0 ... 305029  =      0.000 ...  1220.116 secs...
# Reading 0 ... 430479  =      0.000 ...  1721.916 secs...
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/moabb/datasets/Zhou2016.py:102: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# ...

# %%
scores = []
import numpy as np
for sub in range(len(X_zhou)):
    print('SUB = ',sub)
    zhou_dep = Experiment.single_subject_dependent_cv(X_zhou[sub],y_zhou[sub],
                                                      seed=0,verbose=1,model_name='zhou_dep_sub_1in_'+str(sub),
                                                      benchmarks=['EEGNet','DeepConvNet','EEGene']
                                                     )
    scores.append(zhou_dep)
    np.save('final_report/zhou_dep_1in.npy',scores)
# Out:
# SUB =  0
# batch : 0
# (255, 14, 500) (64, 14, 500)
# method =  covariance
# method =  raw
# method =  fft2
# method =  fft
# method =  cross_correlate
# method =  maxmin
# method =  meanstd
# method =  variance
# method =  spectral_entropy
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
# ...

# %%
Experiment.make_final_report(scores)
# Out:
#               method  accuracy  +-acc  f1-score  +-f1
# 12            EEGene     83.48   7.68     82.89  8.69
# 0         covariance     80.03   8.34     79.79  8.68
# 7           variance     78.89  10.08     78.22 10.64
# 9                all     78.75   6.84     78.27  7.32
# 6            meanstd     78.11   9.51     77.47 10.29
# 11       DeepConvNet     77.84  12.27     74.88 20.55
# 10            EEGNet     76.54  11.34     76.32 12.13
# 4    cross_correlate     75.24  10.46     74.44 11.17
# 8   spectral_entropy     71.00   9.94     70.36 10.08
# 5             maxmin     66.83   9.06     66.17  9.80
# 1                raw     66.60   9.01     64.98 10.32
# 3                fft     56.23   5.56     54.54  6.92
# 2               fft2     54.82   5.73     53.29  5.33
