# %%
import EEGene
import misc
import Benchmarks
from EEGene import EEGene,Processing
from misc import Experiment,Data_Loader,Baseline_model
# Out:
# 2022-12-05 22:05:44.940202: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-05 22:05:44.940246: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:54: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.1.0 and strictly below 2.3.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# ...

# %%
DL = Data_Loader()
X_bcic,y_bcic = DL.load_bcic(sub=-1,fmin=0.5,fmax=50)

# %%
import numpy as np
scores = []
for sub in range(len(X_bcic)):
    print('SUB = ',sub)
    bcic_dep = Experiment.single_subject_dependent_cv(X_bcic[sub],y_bcic[sub],
                                                      seed=0,verbose=1,model_name='bcic_dep_sub_1in'+str(sub),
                                                      benchmarks=['EEGNet','DeepConvNet','EEGene']
                                                     )
    scores.append(bcic_dep)
    np.save('final_report/bcic_dep_1in.npy',scores)
# Out:
# SUB =  0
# batch : 0
# (230, 22, 400) (58, 22, 400)
# method =  covariance
# method =  raw
# method =  fft2
# method =  fft
# method =  cross_correlate
# method =  maxmin
# method =  meanstd
# method =  variance
# method =  spectral_entropy
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
# ...

# %%
Experiment.make_final_report(scores)
# Out:
#               method  accuracy  +-acc  f1-score  +-f1
# 12            EEGene     80.32  12.36     78.71 14.32
# 10            EEGNet     77.82  13.45     77.80 13.88
# 11       DeepConvNet     76.25  17.47     75.45 21.53
# 9                all     74.05  15.23     72.14 17.06
# 4    cross_correlate     71.29  16.08     69.53 17.77
# 7           variance     70.59  15.02     69.61 16.03
# 1                raw     70.49   9.82     68.86 11.10
# 0         covariance     69.95  14.52     68.47 15.75
# 6            meanstd     69.25  15.70     68.61 16.75
# 8   spectral_entropy     66.43  14.67     65.46 15.96
# 5             maxmin     63.68  13.32     62.73 14.20
# 3                fft     57.38   7.40     54.77  9.37
# 2               fft2     56.14   6.30     52.86  7.83
