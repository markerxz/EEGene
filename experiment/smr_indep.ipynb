# %%
import EEGene
import misc
import Benchmarks
from EEGene import EEGene,Processing
from misc import Experiment,Data_Loader,Baseline_model
# Out:
# 2022-12-05 23:37:24.914866: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-05 23:37:24.914921: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:54: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.1.0 and strictly below 2.3.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
DL = Data_Loader()
X_smr,y_smr = DL.load_smr(sub=-1,fmin=0.5,fmax=50)
# Out:
# Choosing from all possible events

# %%
smr_indep = Experiment.subject_independent_cv(X_smr,y_smr,
                                                 seed=0,verbose=1,
                                                 model_name='smr_indep_1',
                                                 benchmarks=['EEGNet','DeepConvNet','EEGene'])
# Out:
# subject :  0
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# deleting
# no delete
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 15, 448, 1)]      0
#
#  conv2d (Conv2D)             (None, 15, 448, 8)        1600
#
#  batch_normalization (BatchN  (None, 15, 448, 8)       32
#  ormalization)
#
#  depthwise_conv2d (Depthwise  (None, 1, 448, 16)       240
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 1, 448, 16)       64
#  hNormalization)
#
#  activation (Activation)     (None, 1, 448, 16)        0
#
#  average_pooling2d (AverageP  (None, 1, 112, 16)       0
#  ooling2D)
#
#  dropout (Dropout)           (None, 1, 112, 16)        0
#
#  separable_conv2d (Separable  (None, 1, 112, 16)       1056
#  Conv2D)
#
#  batch_normalization_2 (Batc  (None, 1, 112, 16)       64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1, 112, 16)        0
#
#  average_pooling2d_1 (Averag  (None, 1, 14, 16)        0
#  ePooling2D)
#
#  dropout_1 (Dropout)         (None, 1, 14, 16)         0
#
#  flatten (Flatten)           (None, 224)               0
#
#  dense (Dense)               (None, 2)                 450
#
#  softmax (Activation)        (None, 2)                 0
#
# =================================================================
# Total params: 3,506
# Trainable params: 3,426
# Non-trainable params: 80
# _________________________________________________________________
# The first kernel size is (1, 200)
# 2022-12-05 23:42:13.890777: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2022-12-05 23:42:13.890829: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: bob
# 2022-12-05 23:42:13.890872: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: bob
# 2022-12-05 23:42:13.891080: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 510.108.3
# 2022-12-05 23:42:13.891112: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 510.85.2
# 2022-12-05 23:42:13.891119: E tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 510.85.2 does not match DSO version 510.108.3 -- cannot find working devices in this configuration
# 2022-12-05 23:42:13.891829: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7162 - accuracy: 0.5109
# 2022-12-05 23:42:28.615022: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 16s 4s/step - loss: 0.7162 - accuracy: 0.5109 - val_loss: 0.6932 - val_accuracy: 0.5312 - lr: 0.0100
# Epoch 2/200
# 4/4 [==============================] - 12s 3s/step - loss: 0.6683 - accuracy: 0.5984 - val_loss: 0.6984 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 3/200
# 4/4 [==============================] - 12s 3s/step - loss: 0.6347 - accuracy: 0.6323 - val_loss: 0.7131 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 4/200
# 4/4 [==============================] - 13s 3s/step - loss: 0.6096 - accuracy: 0.6458 - val_loss: 0.7161 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 5/200
# 4/4 [==============================] - 14s 3s/step - loss: 0.5813 - accuracy: 0.6812 - val_loss: 0.7218 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 6/200
# 4/4 [==============================] - 12s 3s/step - loss: 0.5597 - accuracy: 0.7182 - val_loss: 0.7135 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 7/200
# 4/4 [==============================] - 13s 3s/step - loss: 0.5307 - accuracy: 0.7255 - val_loss: 0.7072 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 8/200
# 4/4 [==============================] - 11s 3s/step - loss: 0.5029 - accuracy: 0.7615 - val_loss: 0.7135 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 9/200
# 4/4 [==============================] - 13s 3s/step - loss: 0.4778 - accuracy: 0.7724 - val_loss: 0.7303 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 10/200
# 4/4 [==============================] - 12s 3s/step - loss: 0.4535 - accuracy: 0.7917 - val_loss: 0.7303 - val_accuracy: 0.5312 - lr: 0.0100
# Epoch 11/200
# 4/4 [==============================] - 10s 3s/step - loss: 0.4512 - accuracy: 0.7776 - val_loss: 0.7392 - val_accuracy: 0.5312 - lr: 0.0100
# Epoch 12/200
# 4/4 [==============================] - 11s 3s/step - loss: 0.4429 - accuracy: 0.7958 - val_loss: 0.7386 - val_accuracy: 0.5250 - lr: 0.0100
# Epoch 13/200
# 4/4 [==============================] - 12s 3s/step - loss: 0.4294 - accuracy: 0.7974 - val_loss: 0.7546 - val_accuracy: 0.5312 - lr: 0.0100
# Epoch 14/200
# 4/4 [==============================] - 12s 3s/step - loss: 0.4193 - accuracy: 0.8052 - val_loss: 0.8814 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 15/200
# 4/4 [==============================] - 12s 3s/step - loss: 0.4162 - accuracy: 0.8115 - val_loss: 0.9132 - val_accuracy: 0.5188 - lr: 0.0100
# Epoch 16/200
# 4/4 [==============================] - 12s 3s/step - loss: 0.4111 - accuracy: 0.8073 - val_loss: 0.9109 - val_accuracy: 0.5312 - lr: 0.0100
# Epoch 17/200
# 4/4 [==============================] - 9s 2s/step - loss: 0.4079 - accuracy: 0.8099 - val_loss: 1.0750 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 18/200
# 4/4 [==============================] - 9s 2s/step - loss: 0.3799 - accuracy: 0.8323 - val_loss: 1.0344 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 19/200
# 4/4 [==============================] - 9s 2s/step - loss: 0.3804 - accuracy: 0.8234 - val_loss: 1.1269 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 20/200
# 4/4 [==============================] - 9s 2s/step - loss: 0.3667 - accuracy: 0.8339 - val_loss: 1.3741 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 21/200
# 4/4 [==============================] - 9s 2s/step - loss: 0.3669 - accuracy: 0.8349 - val_loss: 1.3513 - val_accuracy: 0.5000 - lr: 0.0100
# 2022-12-05 23:46:14.078728: W tensorflow/core/util/tensor_slice_reader.cc:96] Could not open log/smr_indep_1_out_weights.tf: FAILED_PRECONDITION: log/smr_indep_1_out_weights.tf; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.80      0.64        80
#          1.0       0.59      0.29      0.39        80
#
#     accuracy                           0.54       160
#    macro avg       0.56      0.54      0.51       160
# weighted avg       0.56      0.54      0.51       160
#
# F1-score is computed based on binary
# deleting
# no delete
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 15, 448, 1)]      0
#
#  conv2d_2 (Conv2D)           (None, 15, 444, 25)       150
#
#  conv2d_3 (Conv2D)           (None, 1, 444, 25)        9400
#
#  batch_normalization_6 (Batc  (None, 1, 444, 25)       4
#  hNormalization)
#
#  activation_4 (Activation)   (None, 1, 444, 25)        0
#
#  max_pooling2d (MaxPooling2D  (None, 1, 222, 25)       0
#  )
#
#  dropout_4 (Dropout)         (None, 1, 222, 25)        0
#
#  conv2d_4 (Conv2D)           (None, 1, 218, 50)        6300
#
#  batch_normalization_7 (Batc  (None, 1, 218, 50)       4
#  hNormalization)
#
#  activation_5 (Activation)   (None, 1, 218, 50)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 109, 50)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 1, 109, 50)        0
#
#  conv2d_5 (Conv2D)           (None, 1, 105, 100)       25100
#
#  batch_normalization_8 (Batc  (None, 1, 105, 100)      4
#  hNormalization)
#
#  activation_6 (Activation)   (None, 1, 105, 100)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 52, 100)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 1, 52, 100)        0
#
#  conv2d_6 (Conv2D)           (None, 1, 48, 200)        100200
#
#  batch_normalization_9 (Batc  (None, 1, 48, 200)       4
#  hNormalization)
#
#  activation_7 (Activation)   (None, 1, 48, 200)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 24, 200)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 1, 24, 200)        0
#
#  flatten (Flatten)           (None, 4800)              0
#
#  dense (Dense)               (None, 2)                 9602
#
#  activation_8 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 150,768
# Trainable params: 150,760
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/200
# 4/4 [==============================] - ETA: 0s - loss: 7.4447 - accuracy: 0.4745INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 10s 2s/step - loss: 7.4447 - accuracy: 0.4745 - val_loss: 20.7425 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 2/200
# 4/4 [==============================] - ETA: 0s - loss: 6.4471 - accuracy: 0.5130INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 9s 2s/step - loss: 6.4471 - accuracy: 0.5130 - val_loss: 6.9525 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 3/200
# 4/4 [==============================] - ETA: 0s - loss: 2.1612 - accuracy: 0.5031INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 9s 3s/step - loss: 2.1612 - accuracy: 0.5031 - val_loss: 3.4152 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 4/200
# 4/4 [==============================] - ETA: 0s - loss: 1.5925 - accuracy: 0.5120INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 10s 3s/step - loss: 1.5925 - accuracy: 0.5120 - val_loss: 2.4303 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 5/200
# 4/4 [==============================] - ETA: 0s - loss: 1.2094 - accuracy: 0.4948INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 10s 3s/step - loss: 1.2094 - accuracy: 0.4948 - val_loss: 1.1812 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 6/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.9047 - accuracy: 0.5177 - val_loss: 1.2676 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 7/200
# 4/4 [==============================] - ETA: 0s - loss: 0.8923 - accuracy: 0.5391INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 9s 3s/step - loss: 0.8923 - accuracy: 0.5391 - val_loss: 0.8060 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 8/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.7786 - accuracy: 0.5422 - val_loss: 1.1683 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 9/200
# 4/4 [==============================] - 6s 1s/step - loss: 0.7374 - accuracy: 0.5510 - val_loss: 0.8699 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 10/200
# 4/4 [==============================] - 6s 2s/step - loss: 0.7458 - accuracy: 0.5276 - val_loss: 0.8231 - val_accuracy: 0.4187 - lr: 0.0100
# Epoch 11/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.7102 - accuracy: 0.5469 - val_loss: 0.8713 - val_accuracy: 0.4750 - lr: 0.0100
# Epoch 12/200
# 4/4 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.5656INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 9s 2s/step - loss: 0.6939 - accuracy: 0.5656 - val_loss: 0.7737 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 13/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6832 - accuracy: 0.5776 - val_loss: 0.9285 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 14/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6846 - accuracy: 0.5807 - val_loss: 0.8002 - val_accuracy: 0.4000 - lr: 0.0100
# Epoch 15/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6880 - accuracy: 0.5474 - val_loss: 0.8030 - val_accuracy: 0.4563 - lr: 0.0100
# Epoch 16/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6882 - accuracy: 0.5745 - val_loss: 0.8031 - val_accuracy: 0.4625 - lr: 0.0100
# Epoch 17/200
# 4/4 [==============================] - 6s 2s/step - loss: 0.6954 - accuracy: 0.5583 - val_loss: 0.7755 - val_accuracy: 0.4750 - lr: 0.0100
# Epoch 18/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.6801 - accuracy: 0.5964 - val_loss: 0.8177 - val_accuracy: 0.4688 - lr: 0.0100
# Epoch 19/200
# 4/4 [==============================] - 6s 2s/step - loss: 0.6879 - accuracy: 0.5708 - val_loss: 0.9356 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 20/200
# 4/4 [==============================] - ETA: 0s - loss: 0.6831 - accuracy: 0.5698INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 8s 2s/step - loss: 0.6831 - accuracy: 0.5698 - val_loss: 0.7481 - val_accuracy: 0.4688 - lr: 0.0100
# Epoch 21/200
# 4/4 [==============================] - 6s 1s/step - loss: 0.6853 - accuracy: 0.5583 - val_loss: 0.8242 - val_accuracy: 0.4563 - lr: 0.0100
# Epoch 22/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6913 - accuracy: 0.5760 - val_loss: 0.7695 - val_accuracy: 0.4750 - lr: 0.0100
# Epoch 23/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6936 - accuracy: 0.5630 - val_loss: 0.9140 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 24/200
# 4/4 [==============================] - 6s 1s/step - loss: 0.6808 - accuracy: 0.5714 - val_loss: 0.8771 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 25/200
# 4/4 [==============================] - 6s 1s/step - loss: 0.6913 - accuracy: 0.5573 - val_loss: 0.7987 - val_accuracy: 0.3938 - lr: 0.0100
# Epoch 26/200
# 4/4 [==============================] - 6s 2s/step - loss: 0.6896 - accuracy: 0.5771 - val_loss: 0.8097 - val_accuracy: 0.4688 - lr: 0.0100
# Epoch 27/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6780 - accuracy: 0.5714 - val_loss: 0.8103 - val_accuracy: 0.4750 - lr: 0.0100
# Epoch 28/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6832 - accuracy: 0.5776 - val_loss: 0.8394 - val_accuracy: 0.4437 - lr: 0.0100
# Epoch 29/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6807 - accuracy: 0.5781 - val_loss: 0.7937 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 30/200
# 4/4 [==============================] - ETA: 0s - loss: 0.6842 - accuracy: 0.5802INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 9s 2s/step - loss: 0.6842 - accuracy: 0.5802 - val_loss: 0.7475 - val_accuracy: 0.4437 - lr: 0.0100
# Epoch 31/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6831 - accuracy: 0.5724 - val_loss: 0.8566 - val_accuracy: 0.4688 - lr: 0.0100
# Epoch 32/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.7093 - accuracy: 0.5641 - val_loss: 0.9509 - val_accuracy: 0.4812 - lr: 0.0100
# Epoch 33/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.7174 - accuracy: 0.5583 - val_loss: 0.9744 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 34/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6908 - accuracy: 0.5885 - val_loss: 0.8039 - val_accuracy: 0.4000 - lr: 0.0100
# Epoch 35/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.7028 - accuracy: 0.5667 - val_loss: 0.7949 - val_accuracy: 0.4563 - lr: 0.0100
# Epoch 36/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.7001 - accuracy: 0.5547 - val_loss: 0.8188 - val_accuracy: 0.4625 - lr: 0.0100
# Epoch 37/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.7030 - accuracy: 0.5818 - val_loss: 0.8713 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 38/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6983 - accuracy: 0.5792 - val_loss: 0.9524 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 39/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6771 - accuracy: 0.5760 - val_loss: 0.8404 - val_accuracy: 0.4812 - lr: 0.0100
# Epoch 40/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6743 - accuracy: 0.5896 - val_loss: 0.7834 - val_accuracy: 0.4125 - lr: 0.0100
# Epoch 41/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6865 - accuracy: 0.5771 - val_loss: 0.8330 - val_accuracy: 0.4625 - lr: 0.0100
# Epoch 42/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6733 - accuracy: 0.5865 - val_loss: 0.8979 - val_accuracy: 0.5250 - lr: 0.0100
# Epoch 43/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6796 - accuracy: 0.5802 - val_loss: 1.0031 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 44/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.7025 - accuracy: 0.5781 - val_loss: 0.8289 - val_accuracy: 0.4437 - lr: 0.0100
# Epoch 45/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.7108 - accuracy: 0.5609 - val_loss: 0.7850 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 46/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6827 - accuracy: 0.5911 - val_loss: 0.8422 - val_accuracy: 0.4688 - lr: 0.0100
# Epoch 47/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6829 - accuracy: 0.5943 - val_loss: 0.9829 - val_accuracy: 0.5188 - lr: 0.0100
# Epoch 48/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6933 - accuracy: 0.5677 - val_loss: 0.9294 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 49/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6871 - accuracy: 0.5818 - val_loss: 0.7965 - val_accuracy: 0.4187 - lr: 0.0100
# Epoch 50/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6957 - accuracy: 0.5750 - val_loss: 0.7889 - val_accuracy: 0.4938 - lr: 0.0100
# 2022-12-05 23:51:40.176059: W tensorflow/core/util/tensor_slice_reader.cc:96] Could not open log/smr_indep_1_out_weights.tf: FAILED_PRECONDITION: log/smr_indep_1_out_weights.tf; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.78      0.64        80
#          1.0       0.61      0.35      0.44        80
#
#     accuracy                           0.56       160
#    macro avg       0.58      0.56      0.54       160
# weighted avg       0.58      0.56      0.54       160
#
# F1-score is computed based on binary
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# update score after  9
#               method  accuracy  +-acc  f1-score  +-f1
# 12            EEGene     60.25   8.95     52.67 20.19
# 7           variance     59.06   8.52     54.95 17.60
# 6            meanstd     58.44   9.17     58.39 11.77
# 9                all     57.87   6.39     55.02 14.49
# 0         covariance     57.75   5.74     51.15 17.87
# 10            EEGNet     56.25   9.82     44.75 22.63
# 4    cross_correlate     55.62   7.98     53.09 17.81
# 3                fft     54.56   4.43     51.27  5.67
# 1                raw     53.62   5.46     50.80  7.68
# 11       DeepConvNet     51.81   5.84     51.71 12.14
# 5             maxmin     51.81   5.20     47.40 15.26
# 8   spectral_entropy     51.62   6.18     51.44 10.19
# 2               fft2     49.94   4.74     46.49  5.70
# subject :  10
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# deleting
# no delete
# Model: "model_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_41 (InputLayer)       [(None, 15, 448, 1)]      0
#
#  conv2d_120 (Conv2D)         (None, 15, 448, 8)        1600
#
#  batch_normalization_140 (Ba  (None, 15, 448, 8)       32
#  tchNormalization)
#
#  depthwise_conv2d_20 (Depthw  (None, 1, 448, 16)       240
#  iseConv2D)
#
#  batch_normalization_141 (Ba  (None, 1, 448, 16)       64
#  tchNormalization)
#
#  activation_140 (Activation)  (None, 1, 448, 16)       0
#
#  average_pooling2d_40 (Avera  (None, 1, 112, 16)       0
#  gePooling2D)
#
#  dropout_120 (Dropout)       (None, 1, 112, 16)        0
#
#  separable_conv2d_20 (Separa  (None, 1, 112, 16)       1056
#  bleConv2D)
#
#  batch_normalization_142 (Ba  (None, 1, 112, 16)       64
#  tchNormalization)
#
#  activation_141 (Activation)  (None, 1, 112, 16)       0
#
#  average_pooling2d_41 (Avera  (None, 1, 14, 16)        0
#  gePooling2D)
#
#  dropout_121 (Dropout)       (None, 1, 14, 16)         0
#
#  flatten (Flatten)           (None, 224)               0
#
#  dense (Dense)               (None, 2)                 450
#
#  softmax (Activation)        (None, 2)                 0
#
# =================================================================
# Total params: 3,506
# Trainable params: 3,426
# Non-trainable params: 80
# _________________________________________________________________
# The first kernel size is (1, 200)
# Epoch 1/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7209 - accuracy: 0.5156INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 11s 3s/step - loss: 0.7209 - accuracy: 0.5156 - val_loss: 0.6976 - val_accuracy: 0.4812 - lr: 0.0100
# Epoch 2/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.6423 - accuracy: 0.6323 - val_loss: 1.2731 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 3/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.5962 - accuracy: 0.6771 - val_loss: 3.8016 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 4/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.5696 - accuracy: 0.6984 - val_loss: 9.0929 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 5/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.5430 - accuracy: 0.7156 - val_loss: 9.5051 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 6/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.5220 - accuracy: 0.7344 - val_loss: 12.0699 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 7/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.5031 - accuracy: 0.7401 - val_loss: 11.5851 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 8/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4862 - accuracy: 0.7672 - val_loss: 10.4457 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 9/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4841 - accuracy: 0.7542 - val_loss: 9.5729 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 10/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4692 - accuracy: 0.7734 - val_loss: 7.5632 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 11/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4714 - accuracy: 0.7714 - val_loss: 8.3432 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 12/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4613 - accuracy: 0.7682 - val_loss: 6.6641 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 13/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4560 - accuracy: 0.7745 - val_loss: 7.5041 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 14/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4524 - accuracy: 0.7818 - val_loss: 7.3251 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 15/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4508 - accuracy: 0.7781 - val_loss: 5.4894 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 16/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4430 - accuracy: 0.7953 - val_loss: 5.4607 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 17/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4244 - accuracy: 0.8042 - val_loss: 4.8286 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 18/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4329 - accuracy: 0.7901 - val_loss: 4.9008 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 19/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4236 - accuracy: 0.8021 - val_loss: 5.1807 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 20/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4161 - accuracy: 0.8073 - val_loss: 4.1689 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 21/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4162 - accuracy: 0.7958 - val_loss: 4.0559 - val_accuracy: 0.5000 - lr: 0.0100
# 2022-12-06 15:10:07.086857: W tensorflow/core/util/tensor_slice_reader.cc:96] Could not open log/smr_indep_1_out_weights.tf: FAILED_PRECONDITION: log/smr_indep_1_out_weights.tf; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.51      0.55        80
#          1.0       0.57      0.64      0.60        80
#
#     accuracy                           0.57       160
#    macro avg       0.58      0.57      0.57       160
# weighted avg       0.58      0.57      0.57       160
#
# F1-score is computed based on binary
# deleting
# no delete
# Model: "model_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_43 (InputLayer)       [(None, 15, 448, 1)]      0
#
#  conv2d_122 (Conv2D)         (None, 15, 444, 25)       150
#
#  conv2d_123 (Conv2D)         (None, 1, 444, 25)        9400
#
#  batch_normalization_146 (Ba  (None, 1, 444, 25)       4
#  tchNormalization)
#
#  activation_144 (Activation)  (None, 1, 444, 25)       0
#
#  max_pooling2d_80 (MaxPoolin  (None, 1, 222, 25)       0
#  g2D)
#
#  dropout_124 (Dropout)       (None, 1, 222, 25)        0
#
#  conv2d_124 (Conv2D)         (None, 1, 218, 50)        6300
#
#  batch_normalization_147 (Ba  (None, 1, 218, 50)       4
#  tchNormalization)
#
#  activation_145 (Activation)  (None, 1, 218, 50)       0
#
#  max_pooling2d_81 (MaxPoolin  (None, 1, 109, 50)       0
#  g2D)
#
#  dropout_125 (Dropout)       (None, 1, 109, 50)        0
#
#  conv2d_125 (Conv2D)         (None, 1, 105, 100)       25100
#
#  batch_normalization_148 (Ba  (None, 1, 105, 100)      4
#  tchNormalization)
#
#  activation_146 (Activation)  (None, 1, 105, 100)      0
#
#  max_pooling2d_82 (MaxPoolin  (None, 1, 52, 100)       0
#  g2D)
#
#  dropout_126 (Dropout)       (None, 1, 52, 100)        0
#
#  conv2d_126 (Conv2D)         (None, 1, 48, 200)        100200
#
#  batch_normalization_149 (Ba  (None, 1, 48, 200)       4
#  tchNormalization)
#
#  activation_147 (Activation)  (None, 1, 48, 200)       0
#
#  max_pooling2d_83 (MaxPoolin  (None, 1, 24, 200)       0
#  g2D)
#
#  dropout_127 (Dropout)       (None, 1, 24, 200)        0
#
#  flatten_20 (Flatten)        (None, 4800)              0
#
#  dense_20 (Dense)            (None, 2)                 9602
#
#  activation_148 (Activation)  (None, 2)                0
#
# =================================================================
# Total params: 150,768
# Trainable params: 150,760
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/200
# 4/4 [==============================] - ETA: 0s - loss: 8.1862 - accuracy: 0.4901INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 9s 2s/step - loss: 8.1862 - accuracy: 0.4901 - val_loss: 5.2749 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 2/200
# 4/4 [==============================] - ETA: 0s - loss: 2.4592 - accuracy: 0.5073INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 7s 2s/step - loss: 2.4592 - accuracy: 0.5073 - val_loss: 1.2109 - val_accuracy: 0.5500 - lr: 0.0100
# Epoch 3/200
# 4/4 [==============================] - ETA: 0s - loss: 0.9200 - accuracy: 0.5333INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 8s 2s/step - loss: 0.9200 - accuracy: 0.5333 - val_loss: 0.8190 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 4/200
# 4/4 [==============================] - ETA: 0s - loss: 0.8132 - accuracy: 0.5422INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 8s 2s/step - loss: 0.8132 - accuracy: 0.5422 - val_loss: 0.7744 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 5/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7559 - accuracy: 0.5328INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 7s 2s/step - loss: 0.7559 - accuracy: 0.5328 - val_loss: 0.7161 - val_accuracy: 0.5500 - lr: 0.0100
# Epoch 6/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7256 - accuracy: 0.5406INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 8s 2s/step - loss: 0.7256 - accuracy: 0.5406 - val_loss: 0.6965 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 7/200
# 4/4 [==============================] - 4s 984ms/step - loss: 0.7576 - accuracy: 0.5391 - val_loss: 0.7228 - val_accuracy: 0.5250 - lr: 0.0100
# Epoch 8/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.7519 - accuracy: 0.5250 - val_loss: 0.7387 - val_accuracy: 0.5437 - lr: 0.0100
# Epoch 9/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.7665 - accuracy: 0.5406 - val_loss: 0.7747 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 10/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.7591 - accuracy: 0.5250 - val_loss: 0.7567 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 11/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.7392 - accuracy: 0.5370 - val_loss: 0.7555 - val_accuracy: 0.4625 - lr: 0.0100
# Epoch 12/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7243 - accuracy: 0.5521INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 8s 2s/step - loss: 0.7243 - accuracy: 0.5521 - val_loss: 0.6864 - val_accuracy: 0.5562 - lr: 0.0100
# Epoch 13/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.7167 - accuracy: 0.5609 - val_loss: 0.8035 - val_accuracy: 0.4187 - lr: 0.0100
# Epoch 14/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.7014 - accuracy: 0.5505 - val_loss: 0.7018 - val_accuracy: 0.5312 - lr: 0.0100
# Epoch 15/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.7196 - accuracy: 0.5427 - val_loss: 0.7505 - val_accuracy: 0.4437 - lr: 0.0100
# Epoch 16/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.7319 - accuracy: 0.5250 - val_loss: 0.7122 - val_accuracy: 0.5437 - lr: 0.0100
# Epoch 17/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6862 - accuracy: 0.5786 - val_loss: 0.6928 - val_accuracy: 0.5437 - lr: 0.0100
# Epoch 18/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6878 - accuracy: 0.5740 - val_loss: 0.7145 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 19/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6883 - accuracy: 0.5745 - val_loss: 0.7079 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 20/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6858 - accuracy: 0.5667 - val_loss: 0.7158 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 21/200
# 4/4 [==============================] - 4s 940ms/step - loss: 0.6821 - accuracy: 0.5755 - val_loss: 0.7018 - val_accuracy: 0.5562 - lr: 0.0100
# Epoch 22/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6809 - accuracy: 0.5823 - val_loss: 0.7402 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 23/200
# 4/4 [==============================] - ETA: 0s - loss: 0.6726 - accuracy: 0.5922INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 7s 2s/step - loss: 0.6726 - accuracy: 0.5922 - val_loss: 0.6842 - val_accuracy: 0.5437 - lr: 0.0100
# Epoch 24/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6833 - accuracy: 0.5760 - val_loss: 0.7301 - val_accuracy: 0.4750 - lr: 0.0100
# Epoch 25/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6699 - accuracy: 0.5917 - val_loss: 0.7073 - val_accuracy: 0.5312 - lr: 0.0100
# Epoch 26/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6708 - accuracy: 0.5859 - val_loss: 0.7026 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 27/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6679 - accuracy: 0.5813 - val_loss: 0.7089 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 28/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6711 - accuracy: 0.5984 - val_loss: 0.7190 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 29/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6651 - accuracy: 0.5974 - val_loss: 0.7293 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 30/200
# 4/4 [==============================] - 4s 987ms/step - loss: 0.6717 - accuracy: 0.6010 - val_loss: 0.7217 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 31/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6741 - accuracy: 0.5917 - val_loss: 0.7539 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 32/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6665 - accuracy: 0.5984 - val_loss: 0.7047 - val_accuracy: 0.5312 - lr: 0.0100
# Epoch 33/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6680 - accuracy: 0.6042 - val_loss: 0.7486 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 34/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6490 - accuracy: 0.6250 - val_loss: 0.7676 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 35/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6409 - accuracy: 0.6266 - val_loss: 0.7606 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 36/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6388 - accuracy: 0.6286 - val_loss: 0.7964 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 37/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6376 - accuracy: 0.6333 - val_loss: 0.7463 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 38/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6354 - accuracy: 0.6344 - val_loss: 0.8115 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 39/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6333 - accuracy: 0.6380 - val_loss: 0.8334 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 40/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6238 - accuracy: 0.6474 - val_loss: 0.7592 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 41/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6287 - accuracy: 0.6323 - val_loss: 0.8368 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 42/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6239 - accuracy: 0.6391 - val_loss: 0.7884 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 43/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6264 - accuracy: 0.6391 - val_loss: 0.7724 - val_accuracy: 0.5250 - lr: 0.0100
# 2022-12-06 15:13:37.903144: W tensorflow/core/util/tensor_slice_reader.cc:96] Could not open log/smr_indep_1_out_weights.tf: FAILED_PRECONDITION: log/smr_indep_1_out_weights.tf; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.59      0.54        80
#          1.0       0.51      0.42      0.46        80
#
#     accuracy                           0.51       160
#    macro avg       0.51      0.51      0.50       160
# weighted avg       0.51      0.51      0.50       160
#
# F1-score is computed based on binary
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# update score after  10
#               method  accuracy  +-acc  f1-score  +-f1
# 12            EEGene     59.15   9.22     51.70 19.50
# 6            meanstd     58.24   8.76     58.09 11.26
# 7           variance     58.07   8.71     53.29 17.59
# 9                all     58.07   6.13     55.17 13.82
# 0         covariance     56.99   5.98     51.18 17.04
# 10            EEGNet     56.36   9.37     46.13 22.01
# 4    cross_correlate     55.06   7.82     52.35 17.14
# 3                fft     54.32   4.29     51.24  5.41
# 1                raw     53.52   5.22     50.72  7.33
# ...
#
#  batch_normalization_156 (Ba  (None, 1, 112, 16)       64
#  tchNormalization)
#
#  activation_155 (Activation)  (None, 1, 112, 16)       0
#
#  average_pooling2d_45 (Avera  (None, 1, 14, 16)        0
#  gePooling2D)
#
#  dropout_133 (Dropout)       (None, 1, 14, 16)         0
#
#  flatten (Flatten)           (None, 224)               0
#
#  dense (Dense)               (None, 2)                 450
#
#  softmax (Activation)        (None, 2)                 0
#
# =================================================================
# Total params: 3,506
# Trainable params: 3,426
# Non-trainable params: 80
# _________________________________________________________________
# The first kernel size is (1, 200)
# Epoch 1/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7255 - accuracy: 0.5052INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 11s 3s/step - loss: 0.7255 - accuracy: 0.5052 - val_loss: 0.7074 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 2/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.6547 - accuracy: 0.6182 - val_loss: 1.3067 - val_accuracy: 0.5437 - lr: 0.0100
# Epoch 3/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.6130 - accuracy: 0.6552 - val_loss: 2.3747 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 4/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.5629 - accuracy: 0.7156 - val_loss: 4.4789 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 5/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.5278 - accuracy: 0.7312 - val_loss: 6.1304 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 6/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.5032 - accuracy: 0.7583 - val_loss: 8.4462 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 7/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.5011 - accuracy: 0.7526 - val_loss: 7.4503 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 8/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4868 - accuracy: 0.7609 - val_loss: 8.5276 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 9/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4753 - accuracy: 0.7672 - val_loss: 7.9597 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 10/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4668 - accuracy: 0.7781 - val_loss: 7.9120 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 11/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4603 - accuracy: 0.7807 - val_loss: 7.1253 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 12/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4435 - accuracy: 0.7906 - val_loss: 6.6975 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 13/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4339 - accuracy: 0.7922 - val_loss: 6.1111 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 14/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4270 - accuracy: 0.8036 - val_loss: 5.0949 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 15/200
# 4/4 [==============================] - 9s 2s/step - loss: 0.4132 - accuracy: 0.7995 - val_loss: 5.0427 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 16/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4115 - accuracy: 0.8109 - val_loss: 4.7493 - val_accuracy: 0.5063 - lr: 0.0100
# Epoch 17/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4028 - accuracy: 0.8010 - val_loss: 4.8243 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 18/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.4023 - accuracy: 0.8083 - val_loss: 3.7758 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 19/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.3910 - accuracy: 0.8188 - val_loss: 3.4288 - val_accuracy: 0.5188 - lr: 0.0100
# Epoch 20/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.3932 - accuracy: 0.8115 - val_loss: 3.6723 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 21/200
# 4/4 [==============================] - 8s 2s/step - loss: 0.3729 - accuracy: 0.8245 - val_loss: 3.4563 - val_accuracy: 0.5188 - lr: 0.0100
# 2022-12-06 16:29:25.493417: W tensorflow/core/util/tensor_slice_reader.cc:96] Could not open log/smr_indep_1_out_weights.tf: FAILED_PRECONDITION: log/smr_indep_1_out_weights.tf; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.56      0.55        80
#          1.0       0.53      0.50      0.52        80
#
#     accuracy                           0.53       160
#    macro avg       0.53      0.53      0.53       160
# weighted avg       0.53      0.53      0.53       160
#
# F1-score is computed based on binary
# deleting
# no delete
# Model: "model_46"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_47 (InputLayer)       [(None, 15, 448, 1)]      0
#
#  conv2d_134 (Conv2D)         (None, 15, 444, 25)       150
#
#  conv2d_135 (Conv2D)         (None, 1, 444, 25)        9400
#
#  batch_normalization_160 (Ba  (None, 1, 444, 25)       4
#  tchNormalization)
#
#  activation_158 (Activation)  (None, 1, 444, 25)       0
#
#  max_pooling2d_88 (MaxPoolin  (None, 1, 222, 25)       0
#  g2D)
#
#  dropout_136 (Dropout)       (None, 1, 222, 25)        0
#
#  conv2d_136 (Conv2D)         (None, 1, 218, 50)        6300
#
#  batch_normalization_161 (Ba  (None, 1, 218, 50)       4
#  tchNormalization)
#
#  activation_159 (Activation)  (None, 1, 218, 50)       0
#
#  max_pooling2d_89 (MaxPoolin  (None, 1, 109, 50)       0
#  g2D)
#
#  dropout_137 (Dropout)       (None, 1, 109, 50)        0
#
#  conv2d_137 (Conv2D)         (None, 1, 105, 100)       25100
#
#  batch_normalization_162 (Ba  (None, 1, 105, 100)      4
#  tchNormalization)
#
#  activation_160 (Activation)  (None, 1, 105, 100)      0
#
#  max_pooling2d_90 (MaxPoolin  (None, 1, 52, 100)       0
#  g2D)
#
#  dropout_138 (Dropout)       (None, 1, 52, 100)        0
#
#  conv2d_138 (Conv2D)         (None, 1, 48, 200)        100200
#
#  batch_normalization_163 (Ba  (None, 1, 48, 200)       4
#  tchNormalization)
#
#  activation_161 (Activation)  (None, 1, 48, 200)       0
#
#  max_pooling2d_91 (MaxPoolin  (None, 1, 24, 200)       0
#  g2D)
#
#  dropout_139 (Dropout)       (None, 1, 24, 200)        0
#
#  flatten_22 (Flatten)        (None, 4800)              0
#
#  dense_22 (Dense)            (None, 2)                 9602
#
#  activation_162 (Activation)  (None, 2)                0
#
# =================================================================
# Total params: 150,768
# Trainable params: 150,760
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/200
# 4/4 [==============================] - ETA: 0s - loss: 9.2052 - accuracy: 0.4953INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 9s 2s/step - loss: 9.2052 - accuracy: 0.4953 - val_loss: 6.2544 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 2/200
# 4/4 [==============================] - ETA: 0s - loss: 2.8063 - accuracy: 0.5224INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 7s 2s/step - loss: 2.8063 - accuracy: 0.5224 - val_loss: 1.1950 - val_accuracy: 0.5188 - lr: 0.0100
# Epoch 3/200
# 4/4 [==============================] - ETA: 0s - loss: 0.8739 - accuracy: 0.5380INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 8s 2s/step - loss: 0.8739 - accuracy: 0.5380 - val_loss: 0.9101 - val_accuracy: 0.4313 - lr: 0.0100
# Epoch 4/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.9174 - accuracy: 0.5500 - val_loss: 1.2185 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 5/200
# 4/4 [==============================] - ETA: 0s - loss: 1.0432 - accuracy: 0.5141INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 7s 2s/step - loss: 1.0432 - accuracy: 0.5141 - val_loss: 0.8038 - val_accuracy: 0.5250 - lr: 0.0100
# Epoch 6/200
# 4/4 [==============================] - ETA: 0s - loss: 0.8268 - accuracy: 0.5479INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 8s 2s/step - loss: 0.8268 - accuracy: 0.5479 - val_loss: 0.7549 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 7/200
# 4/4 [==============================] - ETA: 0s - loss: 0.7670 - accuracy: 0.5396INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 7s 2s/step - loss: 0.7670 - accuracy: 0.5396 - val_loss: 0.7245 - val_accuracy: 0.4938 - lr: 0.0100
# Epoch 8/200
# 4/4 [==============================] - ETA: 0s - loss: 0.6996 - accuracy: 0.5552INFO:tensorflow:Assets written to: log/smr_indep_1_out_weights.tf/assets
# 4/4 [==============================] - 7s 2s/step - loss: 0.6996 - accuracy: 0.5552 - val_loss: 0.7218 - val_accuracy: 0.5125 - lr: 0.0100
# Epoch 9/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6882 - accuracy: 0.5615 - val_loss: 0.7608 - val_accuracy: 0.3938 - lr: 0.0100
# Epoch 10/200
# 4/4 [==============================] - 4s 983ms/step - loss: 0.6995 - accuracy: 0.5505 - val_loss: 0.7419 - val_accuracy: 0.4625 - lr: 0.0100
# Epoch 11/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6889 - accuracy: 0.5776 - val_loss: 0.7347 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 12/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6898 - accuracy: 0.5562 - val_loss: 0.7554 - val_accuracy: 0.4812 - lr: 0.0100
# Epoch 13/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6836 - accuracy: 0.5693 - val_loss: 0.7437 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 14/200
# 4/4 [==============================] - 4s 972ms/step - loss: 0.6840 - accuracy: 0.5661 - val_loss: 0.7551 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 15/200
# 4/4 [==============================] - 4s 977ms/step - loss: 0.6813 - accuracy: 0.5760 - val_loss: 0.7457 - val_accuracy: 0.4313 - lr: 0.0100
# Epoch 16/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6806 - accuracy: 0.5708 - val_loss: 0.7474 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 17/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6837 - accuracy: 0.5802 - val_loss: 0.7378 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 18/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6874 - accuracy: 0.5646 - val_loss: 0.7702 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 19/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6807 - accuracy: 0.5927 - val_loss: 0.7947 - val_accuracy: 0.3562 - lr: 0.0100
# Epoch 20/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6901 - accuracy: 0.5667 - val_loss: 0.7364 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 21/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6834 - accuracy: 0.5818 - val_loss: 0.7711 - val_accuracy: 0.4313 - lr: 0.0100
# Epoch 22/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6982 - accuracy: 0.5719 - val_loss: 0.7446 - val_accuracy: 0.4875 - lr: 0.0100
# Epoch 23/200
# 4/4 [==============================] - 4s 1s/step - loss: 0.6787 - accuracy: 0.5844 - val_loss: 0.7700 - val_accuracy: 0.4313 - lr: 0.0100
# Epoch 24/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6781 - accuracy: 0.5964 - val_loss: 0.7363 - val_accuracy: 0.4812 - lr: 0.0100
# Epoch 25/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6706 - accuracy: 0.5875 - val_loss: 0.7497 - val_accuracy: 0.4563 - lr: 0.0100
# Epoch 26/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6684 - accuracy: 0.5922 - val_loss: 0.7530 - val_accuracy: 0.4625 - lr: 0.0100
# Epoch 27/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6654 - accuracy: 0.5906 - val_loss: 0.7609 - val_accuracy: 0.4812 - lr: 0.0100
# Epoch 28/200
# 4/4 [==============================] - 5s 1s/step - loss: 0.6746 - accuracy: 0.5948 - val_loss: 0.7485 - val_accuracy: 0.5063 - lr: 0.0100
# 2022-12-06 16:31:52.838269: W tensorflow/core/util/tensor_slice_reader.cc:96] Could not open log/smr_indep_1_out_weights.tf: FAILED_PRECONDITION: log/smr_indep_1_out_weights.tf; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.57        80
#          1.0       0.50      0.35      0.41        80
#
#     accuracy                           0.50       160
#    macro avg       0.50      0.50      0.49       160
# weighted avg       0.50      0.50      0.49       160
#
# F1-score is computed based on binary
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: divide by zero encountered in log2
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)
# /home/jupyter-markerxz/.local/lib/python3.9/site-packages/antropy/entropy.py:249: RuntimeWarning: invalid value encountered in multiply
#   se = -(psd_norm * np.log2(psd_norm)).sum(axis=axis)

# %%
Experiment.make_df(smr_indep)
# Out:
#               method  accuracy  +-acc  f1-score  +-f1
# 12            EEGene     57.81   8.58     48.39 20.40
# 0         covariance     56.25   5.69     49.25 18.89
# 6            meanstd     56.12   8.89     54.83 13.16
# 9                all     56.12   6.69     55.24 12.32
# 7           variance     56.07   8.68     50.81 17.16
# 10            EEGNet     55.62   8.43     48.74 20.28
# 3                fft     54.15   4.22     52.28  5.60
# 1                raw     53.57   4.63     50.63  6.80
# 4    cross_correlate     53.53   7.62     52.87 15.32
# 11       DeepConvNet     51.70   5.00     50.32 12.06
# 2               fft2     51.07   4.48     48.50  5.77
# 8   spectral_entropy     50.98   5.53     49.49 10.55
# 5             maxmin     50.98   5.64     46.89 13.50

# %%
smr_indep['EEGene']
# Out:
# [{'accuracy': 0.51875, 'f1-score': 0.40310077519379844},
#  {'accuracy': 0.58125, 'f1-score': 0.32323232323232326},
#  {'accuracy': 0.74375, 'f1-score': 0.6870229007633588},
#  {'accuracy': 0.63125, 'f1-score': 0.714975845410628},
#  {'accuracy': 0.53125, 'f1-score': 0.15730337078651682},
#  {'accuracy': 0.55, 'f1-score': 0.30769230769230765},
#  {'accuracy': 0.63125, 'f1-score': 0.730593607305936},
#  {'accuracy': 0.5375, 'f1-score': 0.6542056074766355},
#  {'accuracy': 0.78125, 'f1-score': 0.7445255474452555},
#  {'accuracy': 0.51875, 'f1-score': 0.544378698224852},
#  {'accuracy': 0.48125, 'f1-score': 0.41958041958041953},
#  {'accuracy': 0.54375, 'f1-score': 0.5165562913907285},
#  {'accuracy': 0.51875, 'f1-score': 0.47619047619047616},
#  {'accuracy': 0.525, 'f1-score': 0.09523809523809523}]
